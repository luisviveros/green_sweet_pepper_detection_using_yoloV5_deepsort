# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Sep  7 23:46:09 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
SOURCE_VIDEO_PATH = f"/content/Sample1_Tesis_350FPS.mp4"

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **23.01.2023** with version **YOLOv8.0.17**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.173 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 26.5/166.8 GB disk)

# %% [markdown]
# ## Install ByteTrack
#
# [ByteTrack](https://github.com/ifzhang/ByteTrack) is great tracker but a bit poorly packaged. We need to jump through some fire hoops to make it work in tandem with [YOLOv8](https://github.com/ultralytics/ultralytics).

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils
#
# Unfortunately, we have to manually match the bounding boxes coming from our model with those created by the tracker.

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
# !unzip /content/yolov8_tesis.zip
# Out:
# Archive:  /content/yolov8_tesis.zip
#   inflating: weights/last.pt
#   inflating: weights/best.pt

# %%
# settings
MODEL = "weights/best.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients

# %%
model.model.names
# Out:
# {0: 'Early-Mid', 1: 'Immature', 2: 'Mature', 3: 'Mid-Late'}

# %% [markdown]
# ## Predict and annotate single frame

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [0,1,2,3]

# %%
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
# annotate and display frame
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))
# Out:
# 0: 384x640 (no detections), 72.6ms
# Speed: 14.5ms preprocess, 72.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Predict and annotate whole video

# %%
# settings
LINE_START = Point(100,25)
LINE_END = Point(100,1050)

TARGET_VIDEO_PATH = f"{HOME}/tracking-result7.mp4"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=1920, height=1080, fps=24, total_frames=2732)

# %%
from tqdm.notebook import tqdm


# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate( frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        sink.write_frame(frame)
# Out:
#   0%|          | 0/2732 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 8 Immatures, 2 Matures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 2 Matures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 2 Matures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 Immatures, 1 Mature, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 Immatures, 1 Mature, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 7 Immatures, 2 Matures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 7 Immatures, 1 Mature, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 1 Mature, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 1 Mature, 10.9ms
# Speed: 3.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 1 Mature, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 Immatures, 1 Mature, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 8 Immatures, 1 Mature, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mature, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 Immatures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 Immatures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 10 Immatures, 2 Matures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 2 Matures, 10.8ms
# Speed: 2.8ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 Immatures, 2 Matures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 Immatures, 2 Matures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 2 Matures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 Immatures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 Immatures, 2 Matures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 Immatures, 2 Matures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 2 Matures, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 Immatures, 1 Mature, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 Immatures, 1 Mature, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 2 Matures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 2 Matures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 Immatures, 2 Matures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 3 Matures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 3 Matures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 Immatures, 1 Mature, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 Immatures, 3 Matures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 Immatures, 3 Matures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 12 Immatures, 3 Matures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 Immatures, 2 Matures, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 Immatures, 2 Matures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 3 Matures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 Immatures, 3 Matures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 Immatures, 3 Matures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 Immatures, 2 Matures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 Immatures, 3 Matures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 17 Immatures, 3 Matures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 17 Immatures, 2 Matures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 16 Immatures, 3 Matures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 14 Immatures, 3 Matures, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 13 Immatures, 3 Matures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 14 Immatures, 3 Matures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 3 Matures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 16 Immatures, 3 Matures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 16 Immatures, 2 Matures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 16 Immatures, 3 Matures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 17 Immatures, 3 Matures, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 14 Immatures, 3 Matures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 12 Immatures, 3 Matures, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 13 Immatures, 3 Matures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 17 Immatures, 3 Matures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 2 Matures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 15 Immatures, 2 Matures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 3 Matures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 14 Immatures, 3 Matures, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 2 Matures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 13 Immatures, 3 Matures, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 17 Immatures, 3 Matures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 19 Immatures, 2 Matures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 16 Immatures, 2 Matures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 14 Immatures, 3 Matures, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 14 Immatures, 3 Matures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 14 Immatures, 3 Matures, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 12 Immatures, 3 Matures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 2 Matures, 10.8ms
# Speed: 2.8ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 3 Matures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 3 Matures, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 17 Immatures, 2 Matures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 15 Immatures, 2 Matures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 3 Matures, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 3 Matures, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 3 Matures, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 10.9ms
# Speed: 3.2ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 3 Matures, 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 18 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 16 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 14 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 3 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 16 Immatures, 2 Matures, 1 Mid-Late, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 3 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 12 Immatures, 3 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 3 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 3 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.4ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 10 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 10 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 17 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 15 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 16 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 10 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 2 Matures, 1 Mid-Late, 10.9ms
# Speed: 3.2ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 12 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 13 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 13 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 13 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 14 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 13 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 11 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Early-Mids, 12 Immatures, 1 Mature, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 13 Immatures, 1 Mature, 1 Mid-Late, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 10 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 12 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 10 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 12 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 10 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 10 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 11 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 10 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 10 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 10 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 8 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 8 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 8 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 8 Immatures, 1 Mid-Late, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 9 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.8ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Early-Mid, 8 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 1 Mid-Late, 10.9ms
# Speed: 3.8ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 1 Mid-Late, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 1 Mid-Late, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 1 Mid-Late, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Immatures, 1 Mid-Late, 10.8ms
# ...
#
# 0: 384x640 5 Immatures, 10.9ms
# Speed: 3.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Immatures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Immatures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Immatures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Immatures, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Immatures, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 3.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Immatures, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Immatures, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Immature, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Immature, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Immature, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
def visualize_tracking_results(tracking_results):
  """Visualizes the tracking results.

  Args:
    tracking_results: The tracking results.

  Returns:
    A visualization of the tracking results.
  """

  fig, ax = plt.subplots()

  # Plot the ground truth tracks.
  for track in tracking_results.tracks:
    ax.plot(track.bbox[:, 0], track.bbox[:, 1], color="green")

  # Plot the predicted tracks.
  for detection in tracking_results.detections:
    ax.plot(detection.bbox[:, 0], detection.bbox[:, 1], color="red")

  ax.legend(["Ground truth", "Predicted"])
  ax.set_title("Tracking results")

  return fig
